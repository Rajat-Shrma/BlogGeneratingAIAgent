# %%
from tavily import TavilyClient
import os
tavily_client = TavilyClient(api_key=f"{os.getenv('TAVILY_API_KEY')}")
response = tavily_client.search("Who is Leo Messi?")

print(response)
# Out:
# {'query': 'Who is Leo Messi?', 'response_time': 0.75, 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://en.wikipedia.org/wiki/Lionel_Messi', 'title': 'Lionel Messi - Wikipedia', 'content': 'Lionel Andrés "Leo" Messi (born 24 June 1987) is an Argentine professional footballer who plays as a forward for and captains both Major League Soccer club', 'score': 0.9967775, 'raw_content': None}, {'url': 'https://messi.com/en/', 'title': 'Web oficial Leo Messi jugador del Inter de Miami – messi.com', 'content': 'Official website of Lionel Messi, professional soccer player and world champion with the Argentine national team.', 'score': 0.99444515, 'raw_content': None}, {'url': 'https://www.fcbarcelona.com/en/card/2214377/leo-messi', 'title': 'Leo Messi - FC Barcelona', 'content': "* caret-down label.aria.bellblockcolour Barça Teams. ###### Leo Messi and the treble trophies from 2009: Copa del Rey, Champions League and Liga. Messi (Rosario, Argentina, 24 June 1987) is the greatest player of all time and FC Barcelona record setter. Getting better every season, Messi and Barça won 35 trophies during the Argentine's time at the Club, including the six won in 2009 and the treble in 2015. Messi’s individual achievements are also unprecedented: six Ballon d’Or awards, six times Champions League top scorer, six times Golden Shoe winner, eight times ‘Pichichi’ (top scorer) in La Liga, Ballon d’Or winner at the 2014 World Cup, FIFA World Player of the Year in 2009 and FIFA The Best winner in 2019. With the Argentina national side Messi played in four World Cups (2006, 2010, 2014, 2018) as a Barça player, losing in the final in 2014 in Brazil against Germany. * Only player to win Ballon d’Or, FIFA World Player, La Liga top scorer and Golden Shoe in same season (2009/10).", 'score': 0.9859364, 'raw_content': None}, {'url': 'https://www.imdb.com/name/nm2177779/', 'title': 'Lionel Messi - IMDb', 'content': "Lionel Messi is a football player from Argentina who plays for Inter Miami. He has won the Ballon D'Or, the annual award given to the best player in the world,", 'score': 0.9829547, 'raw_content': None}, {'url': 'https://www.instagram.com/leomessi/', 'title': 'Leo Messi (@leomessi) · Miami, FL - Instagram', 'content': '511M Followers, 361 Following, 1459 Posts - Leo Messi (@leomessi) on Instagram: "Bienvenidos a la cuenta oficial de Instagram de Leo Messi / Welcome to the', 'score': 0.9757624, 'raw_content': None}], 'request_id': 'e0375139-af4e-4164-8b8f-febccd630322'}

# %%
from langchain_community.tools.tavily_search import TavilySearchResults
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain_community.tools.tavily_search import TavilySearchResults
#
# ModuleNotFoundError: No module named 'langchain_community'
